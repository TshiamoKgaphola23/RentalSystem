# %% [markdown]
# ### Connecting to Postgresql

# %%
# pip install sqlalchemy

# %%
# pip install psycopg2-binary

# %%
# %load_ext sql
from sqlalchemy import create_engine
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:@localhost:5432/postgres

# %%
# %%sql
# CREATE TABLE Movies20 (
#     Poster_Link char(255),
#     Movies char(255),
#     Released_year int,
#     Runtime char(255),
#     Genre char(255),
#     Rating char(255),
#     Director char(255),
#     Star1 char(255),
#     Star2 char(255),
#     Star3 char(255),
#     Star4 char(255),
#     Copies_available int,
#     Prices int
#     )
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %%
# %%sql
# INSERT INTO Movies20 (Poster_Link, Movies , Released_year, Runtime , Genre , Rating, Director , Star1 , Star2 , Star3 , Star4 , Copies_available , Prices)
# VALUES ( 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg','The Shawshank Redemption',1994,142,'Drama','Frank Darabont','Tim Robbins','Morgan Freeman','Bob Gunton','SWilliam Sadler', 34, 186),
# ( 'lIInk','FFGHJn',1994, 9.3,142,'Drama','Frank Darabont','Tim Robbins','Morgan Freeman','Bob Gunton','SWilliam Sadler', 34, 186 ),
# ( 'lnk','VVDG',1994, 9.3,142,'Drama','Frank Darabont','Tim Robbins','Morgan Freeman','Bob Gunton','SWilliam Sadler', 34, 186),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),
# ('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184)
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# (psycopg2.errors.SyntaxError) INSERT has more target columns than expressions
# LINE 1: ..., Star1 , Star2 , Star3 , Star4 , Copies_available , Prices)
#                                                                 ^
#
# [SQL: INSERT INTO Movies20 (Poster_Link, Movies , Released_year, Runtime , Genre , Rating, Director , Star1 , Star2 , Star3 , Star4 , Copies_available , Prices)
# VALUES ( 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg','The Shawshank Redemption',1994,142,'Drama','Frank Darabont','Tim Robbins','Morgan Freeman','Bob Gunton','SWilliam Sadler', 34, 186),
# ( 'lIInk','FFGHJn',1994, 9.3,142,'Drama','Frank Darabont','Tim Robbins','Morgan Freeman','Bob Gunton','SWilliam Sadler', 34, 186 ),
# ( 'lnk','VVDG',1994, 9.3,142,'Drama','Frank Darabont','Tim Robbins','Morgan Freeman','Bob Gunton','SWilliam Sadler', 34, 186),
# ...

# %%
# %%sql
# SELECT * FROM Movies20
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 3 rows affected.
# ...

# %%
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184), 
('llin', 'The Godfather', 1972, 175, 9.2, 'Crime', 'Francis Ford Coppola','Marlon Brando', 'AL Pacino', 'James Cean', 'Diane Keaton', 1, 184),

# %%
# %%sql
# COPY Movies17 (Poster_Link, Movies, Released_year, Runtime, Genre, Rating, Director, Star1, Star2, Star3, Star4, Copies_available, prices) FROM '/Users/damacm1143/Desktop/movies.csv' DELIMITER ',' CSV HEADER;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# (psycopg2.errors.BadCopyFileFormat) missing data for column "genre"
# CONTEXT:  COPY movies17, line 2: "https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGde..."
#
# [SQL: COPY Movies17 (Poster_Link, Movies, Released_year, Runtime, Genre, Rating, Director, Star1, Star2, Star3, Star4, Copies_available, prices) FROM '/Users/damacm1143/Desktop/movies.csv' DELIMITER ',' CSV HEADER;]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)

# %%
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 3 rows affected.
# []

# %%
# %%sql
# CREATE TABLE Customer2 (
#     PersonID char(255) PRIMARY KEY,
#     Name char(255),
#     address char(255),
#     city char(255)
#     )
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %%
# %%sql
# INSERT INTO Customer1 ( PersonID , Name , address , city )
# VALUES (
#     'OOKIU',
#     'TSHIAMO',
#     'TTSHIA@GMAIL.COM',
#     'TEMBISA'
#     )
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM Customer1
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 2 rows affected.
# ...

# %%
# %%sql
# CREATE TABLE Rentals4 (
# Name varchar(255),
# surname varchar(255),
# id_number int,
# email varchar(255),
# phone int,
# rental_date DATE,
# return_date DATE
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %%
# %%sql
# INSERT INTO Rentals4 ( Name, surname, id_number, email, phone, rental_date , return_date )
# VALUES ('THOMAS', 'CHIPI', 0987666544, 'TSHIAMO@gmail.com', 823541398, '2003-8-18' , '2009-3-23')
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# []

# %%
# %sql  SELECT * FROM Rentals4
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 2 rows affected.
# [('THOMAS', 'CHIPI', 987666544, 'TSHIAMO@gmail.com', 823541398, datetime.date(2003, 8, 18), datetime.date(2009, 3, 23)),
#  ('THOMAS', 'CHIPI', 987666544, 'TSHIAMO@gmail.com', 823541398, datetime.date(2003, 8, 18), datetime.date(2009, 3, 23))]
